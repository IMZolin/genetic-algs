# %%
import json
from benchmark import run_all_benchmarks, draw_plots_from_json

# %%
ARRAY_SIZES = [10_000, 100_000, 1_000_000, 10_000_000, 20_000_000, 50_000_000, 100_000_000, 200_000_000, 500_000_000, 1_000_000_000]
Q = 10_000
results = run_all_benchmarks(ARRAY_SIZES, Q)

with open("results.json", "w") as f:
    json.dump(results, f, indent=4)

print("\nSaved results to results.json")
draw_plots_from_json("results.json", "graphics.png")
# Out:
# === Benchmark n = 10000 ===
# Completed: n=10000, method=iterative, time=0.0155s, cpu=0.0160s
# Completed: n=10000, method=recursive, time=0.0151s, cpu=0.0152s
# Completed: n=10000, method=localvars, time=0.0100s, cpu=0.0100s
# Completed: n=10000, method=bisect, time=0.0017s, cpu=0.0017s
# Completed: n=10000, method=numpy, time=0.0102s, cpu=0.0102s
#
# === Benchmark n = 100000 ===
# Completed: n=100000, method=iterative, time=0.0110s, cpu=0.0109s
# Completed: n=100000, method=recursive, time=0.0139s, cpu=0.0138s
# Completed: n=100000, method=localvars, time=0.0102s, cpu=0.0102s
# Completed: n=100000, method=bisect, time=0.0020s, cpu=0.0020s
# Completed: n=100000, method=numpy, time=0.0088s, cpu=0.0088s
#
# === Benchmark n = 1000000 ===
# Completed: n=1000000, method=iterative, time=0.0142s, cpu=0.0142s
# Completed: n=1000000, method=recursive, time=0.0176s, cpu=0.0176s
# Completed: n=1000000, method=localvars, time=0.0134s, cpu=0.0134s
# ...
